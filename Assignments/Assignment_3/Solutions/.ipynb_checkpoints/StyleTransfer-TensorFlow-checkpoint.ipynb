# %% [markdown]
# # Style Transfer
# In this notebook we will implement the style transfer technique from ["Image Style Transfer Using Convolutional Neural Networks" (Gatys et al., CVPR 2015)](http://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/Gatys_Image_Style_Transfer_CVPR_2016_paper.pdf).
#
# The general idea is to take two images, and produce a new image that reflects the content of one but the artistic "style" of the other. We will do this by first formulating a loss function that matches the content and style of each respective image in the feature space of a deep network, and then performing gradient descent on the pixels of the image itself.
#
# The deep network we use as a feature extractor is [SqueezeNet](https://arxiv.org/abs/1602.07360), a small model that has been trained on ImageNet. You could use any network, but we chose SqueezeNet here for its small size and efficiency.
#
# Here's an example of the images you'll be able to produce by the end of this notebook:
#
# ![caption](example_styletransfer.png)

# %% [markdown]
# ## Setup

# %%
import os
import numpy as np
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt
import tensorflow as tf

# Helper functions to deal with image preprocessing
from cs231n.image_utils import load_image, preprocess_image, deprocess_image
from cs231n.classifiers.squeezenet import SqueezeNet

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

def rel_error(x,y):
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# Older versions of scipy.misc.imresize yield different results
# from newer versions, so we check to make sure scipy is up to date.
def check_scipy():
    import scipy
    version = scipy.__version__.split('.')
    if int(version[0]) < 1:
        assert int(version[1]) >= 16, "You must install SciPy >= 0.16.0 to complete this notebook."

check_scipy()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Load the pretrained SqueezeNet model. This model has been ported from PyTorch, see `cs231n/classifiers/squeezenet.py` for the model architecture.
#
# To use SqueezeNet, you will need to first **download the weights** by descending into the `cs231n/datasets` directory and running `get_squeezenet_tf.sh` . Note that if you ran `get_assignment3_data.sh` then SqueezeNet will already be downloaded.

# %%
# Load pretrained SqueezeNet model
SAVE_PATH = 'cs231n/datasets/squeezenet.ckpt'
if not os.path.exists(SAVE_PATH + ".index"):
    raise ValueError("You need to download SqueezeNet!")

# %%
model=SqueezeNet()
model.load_weights(SAVE_PATH)
model.trainable=False

# Load data for testing
content_img_test = preprocess_image(load_image('styles/tubingen.jpg', size=192))[None]
style_img_test = preprocess_image(load_image('styles/starry_night.jpg', size=192))[None]
answers = np.load('style-transfer-checks-tf.npz')

print(content_img_test.shape)
dir(answers)
# Out:
# (1, 192, 256, 3)
# ['__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_files',
#  'allow_pickle',
#  'close',
#  'f',
#  'fid',
#  'files',
#  'get',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'keys',
#  'pickle_kwargs',
#  'values',
#  'zip']

# %% [markdown]
# ## Computing Loss
#
# We're going to compute the three components of our loss function now. The loss function is a weighted sum of three terms: content loss + style loss + total variation loss. You'll fill in the functions that compute these weighted terms below.

# %% [markdown]
# ## Content loss
# We can generate an image that reflects the content of one image and the style of another by incorporating both in our loss function. We want to penalize deviations from the content of the content image and deviations from the style of the style image. We can then use this hybrid loss function to perform gradient descent **not on the parameters** of the model, but instead **on the pixel values** of our original image.
#
# Let's first write the content loss function. Content loss measures how much the feature map of the generated image differs from the feature map of the source image. We only care about the content representation of one layer of the network (say, layer $\ell$), that has feature maps $A^\ell \in \mathbb{R}^{1 \times H_\ell \times W_\ell \times C_\ell}$. $C_\ell$ is the number of filters/channels in layer $\ell$, $H_\ell$ and $W_\ell$ are the height and width. We will work with reshaped versions of these feature maps that combine all spatial positions into one dimension. Let $F^\ell \in \mathbb{R}^{M_\ell \times C_\ell}$ be the feature map for the current image and $P^\ell \in \mathbb{R}^{M_\ell \times C_\ell}$ be the feature map for the content source image where $M_\ell=H_\ell\times W_\ell$ is the number of elements in each feature map. Each row of $F^\ell$ or $P^\ell$ represents the vectorized activations of a particular filter, convolved over all positions of the image. Finally, let $w_c$ be the weight of the content loss term in the loss function.
#
# Then the content loss is given by:
#
# $L_c = w_c \times \sum_{i,j} (F_{ij}^{\ell} - P_{ij}^{\ell})^2$

# %%
def content_loss(content_weight, content_current, content_original):
    """
    Compute the content loss for style transfer.
    
    Inputs:
    - content_weight: scalar constant we multiply the content_loss by.
    - content_current: features of the current image, Tensor with shape [1, height, width, channels]
    - content_target: features of the content image, Tensor with shape [1, height, width, channels]
    
    Returns:
    - scalar content loss
    """
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
    # Num channels
    C = content_current.shape[-1]
    
    content_current = tf.reshape(tf.squeeze(content_current), [-1, C]) # Shape after reshape: (H*W) x C
    content_original = tf.reshape(tf.squeeze(content_original), [-1, C])
    
    content_loss_out = tf.reduce_sum((content_current-content_original)**2) * content_weight
    
    return content_loss_out
    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# %%
# We provide this helper code which takes an image, a model (cnn), and returns a list of
# feature maps, one per layer.
def extract_features(x, cnn):
    """
    Use the CNN to extract features from the input image x.
    
    Inputs:
    - x: A Tensor of shape (N, H, W, C) holding a minibatch of images that
      will be fed to the CNN.
    - cnn: A Tensorflow model that we will use to extract features.
    
    Returns:
    - features: A list of feature for the input images x extracted using the cnn model.
      features[i] is a Tensor of shape (N, H_i, W_i, C_i); recall that features
      from different layers of the network may have different numbers of channels (C_i) and
      spatial dimensions (H_i, W_i).
    """
    features = []
    prev_feat = x
#     print(cnn.net.layers)
#     print(dir(cnn))
    for i, layer in enumerate(cnn.net.layers[:-2]):
#         print(layer.name)
        next_feat = layer(prev_feat)
        features.append(next_feat)
        prev_feat = next_feat
    return features

# %% [markdown]
# Test your content loss. The error should be less than 1e-8.

# %%
def content_loss_test(correct):
    content_layer = 2
    content_weight = 6e-2
    c_feats = extract_features(content_img_test, model)[content_layer]
    bad_img = tf.zeros(content_img_test.shape)
    feats = extract_features(bad_img, model)[content_layer]
    student_output = content_loss(content_weight, c_feats, feats)
    error = rel_error(correct, student_output)
    print('Maximum error is {:.3f}'.format(error))

content_loss_test(answers['cl_out'])
# Out:
# Maximum error is 0.000

# %% [markdown]
# ## Style loss
# Now we can tackle the style loss. For a given layer $\ell$, the style loss is defined as follows:
#
# First, compute the Gram matrix G which represents the correlations between the responses of each filter, where F is as above. The Gram matrix is an approximation to the covariance matrix -- we want the activation statistics of our generated image to match the activation statistics of our style image, and matching the (approximate) covariance is one way to do that. There are a variety of ways you could do this, but the Gram matrix is nice because it's easy to compute and in practice shows good results.
#
# Given a feature map $F^\ell$ of shape $(M_\ell, C_\ell)$, the Gram matrix has shape $(C_\ell, C_\ell)$ and its elements are given by:
#
# $$G_{ij}^\ell  = \sum_k F^{\ell}_{ki} F^{\ell}_{kj}$$
#
# Assuming $G^\ell$ is the Gram matrix from the feature map of the current image, $A^\ell$ is the Gram Matrix from the feature map of the source style image, and $w_\ell$ a scalar weight term, then the style loss for the layer $\ell$ is simply the weighted Euclidean distance between the two Gram matrices:
#
# $$L_s^\ell = w_\ell \sum_{i, j} \left(G^\ell_{ij} - A^\ell_{ij}\right)^2$$
#
# In practice we usually compute the style loss at a set of layers $\mathcal{L}$ rather than just a single layer $\ell$; then the total style loss is the sum of style losses at each layer:
#
# $$L_s = \sum_{\ell \in \mathcal{L}} L_s^\ell$$
#
# Begin by implementing the Gram matrix computation below:

# %%
def gram_matrix(features, normalize=True):
    """
    Compute the Gram matrix from features.
    
    Inputs:
    - features: Tensor of shape (1, H, W, C) giving features for
      a single image.
    - normalize: optional, whether to normalize the Gram matrix
        If True, divide the Gram matrix by the number of neurons (H * W * C)
    
    Returns:
    - gram: Tensor of shape (C, C) giving the (optionally normalized)
      Gram matrices for the input image.
    """
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    _,H, W, C = features.shape
    
#     print("H:{}, W:{}, C:{}".format(H, W,C))
    
    resh_features = tf.reshape(tf.squeeze(features),[-1, C]) # Shape of resh_features: (H*W) x C
        
    gram = tf.linalg.matmul(tf.transpose(resh_features), resh_features)
    
    if normalize:
        gram = gram * (1/(H*W*C))
    
    return gram
    

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# %% [markdown]
# Test your Gram matrix code. You should see errors less than 0.001.

# %%
def gram_matrix_test(correct):
    gram = gram_matrix(extract_features(style_img_test, model)[4]) ### 4 instead of 5 - second MaxPooling layer
    error = rel_error(correct, gram)
    print('Maximum error is {:.3f}'.format(error))

gram_matrix_test(answers['gm_out'])
# Out:
# Maximum error is 0.000

# %% [markdown]
# Next, implement the style loss:

# %%
def style_loss(feats, style_layers, style_targets, style_weights):
    """
    Computes the style loss at a set of layers.
    
    Inputs:
    - feats: list of the features at every layer of the current image, as produced by
      the extract_features function.
    - style_layers: List of layer indices into feats giving the layers to include in the
      style loss.
    - style_targets: List of the same length as style_layers, where style_targets[i] is
      a Tensor giving the Gram matrix of the source style image computed at
      layer style_layers[i].
    - style_weights: List of the same length as style_layers, where style_weights[i]
      is a scalar giving the weight for the style loss at layer style_layers[i].
      
    Returns:
    - style_loss: A Tensor containing the scalar style loss.
    """
    # Hint: you can do this with one for loop over the style layers, and should
    # not be short code (~5 lines). You will need to use your gram_matrix function.
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
    style_loss_out = tf.constant(0.0)
#     style_loss_out = tf.Variable(0.0, name='style')
    print(style_loss_out)
    for i,layer_id in enumerate(style_layers):
        gram_current = gram_matrix(feats[layer_id])
        
        style_loss_out = style_loss_out + style_weights[i] * tf.reduce_sum((style_targets[i]-gram_current)**2)
#         style_loss_out.assign_add(style_weights[i] * tf.reduce_sum((style_targets[i]-gram_current)**2))
    
    return style_loss_out
        


    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# %% [markdown]
# Test your style loss implementation. The error should be less than 0.001.

# %%
def style_loss_test(correct):
    style_layers = [0, 3, 5, 6]
    style_weights = [300000, 1000, 15, 3]
    
    c_feats = extract_features(content_img_test, model)
    feats = extract_features(style_img_test, model)
    style_targets = []
    for idx in style_layers:
        style_targets.append(gram_matrix(feats[idx]))
                             
    s_loss = style_loss(c_feats, style_layers, style_targets, style_weights)
    error = rel_error(correct, s_loss)
    print('Error is {:.3f}'.format(error))

style_loss_test(answers['sl_out'])
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32)
# Error is 0.000

# %% [markdown]
# ## Total-variation regularization
# It turns out that it's helpful to also encourage smoothness in the image. We can do this by adding another term to our loss that penalizes wiggles or "total variation" in the pixel values.
#
# You can compute the "total variation" as the sum of the squares of differences in the pixel values for all pairs of pixels that are next to each other (horizontally or vertically). Here we sum the total-variation regualarization for each of the 3 input channels (RGB), and weight the total summed loss by the total variation weight, $w_t$:
#
# $L_{tv} = w_t \times \left(\sum_{c=1}^3\sum_{i=1}^{H-1}\sum_{j=1}^{W} (x_{i+1,j,c} - x_{i,j,c})^2 + \sum_{c=1}^3\sum_{i=1}^{H}\sum_{j=1}^{W - 1} (x_{i,j+1,c} - x_{i,j,c})^2\right)$
#
# In the next cell, fill in the definition for the TV loss term. To receive full credit, your implementation should not have any loops.

# %%
def tv_loss(img, tv_weight):
    """
    Compute total variation loss.
    
    Inputs:
    - img: Tensor of shape (1, H, W, 3) holding an input image.
    - tv_weight: Scalar giving the weight w_t to use for the TV loss.
    
    Returns:
    - loss: Tensor holding a scalar giving the total variation loss
      for img weighted by tv_weight.
    """
    # Your implementation should be vectorized and not require any loops!
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

#     img = tf.squeeze(img)
    
    first_sum = tf.reduce_sum((img[:,1:,:,:] - img[:,0:-1,: , :])**2)
    
    second_sum = tf.reduce_sum((img[:,:,1:,:] - img[:,:,0:-1,:])**2)
    
        
#     first_sum = tf.reduce_sum((img[:,1:,:,:] - img[:,0:-1,:,:])**2)
    
#     second_sum = tf.reduce_sum((img[:,1:,:] - img[:,0:-1,:])**2)
    
    tv_loss_out = tv_weight * (first_sum + second_sum)
    
    return tv_loss_out

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# %% [markdown]
# Test your TV loss implementation. Error should be less  than 0.001.

# %%
def tv_loss_test(correct):
    tv_weight = 2e-2
    t_loss = tv_loss(content_img_test, tv_weight)
    error = rel_error(correct, t_loss)
    print('Error is {:.3f}'.format(error))

tv_loss_test(answers['tv_out'])
# Out:
# Error is 0.000

# %% [markdown]
# ## Style Transfer

# %% [markdown]
# Lets put it all together and make some beautiful images! The `style_transfer` function below combines all the losses you coded up above and optimizes for an image that minimizes the total loss.

# %%
def style_transfer(content_image, style_image, image_size, style_size, content_layer, content_weight,
                   style_layers, style_weights, tv_weight, init_random = False):
    """Run style transfer!
    
    Inputs:
    - content_image: filename of content image
    - style_image: filename of style image
    - image_size: size of smallest image dimension (used for content loss and generated image)
    - style_size: size of smallest style image dimension
    - content_layer: layer to use for content loss
    - content_weight: weighting on content loss
    - style_layers: list of layers to use for style loss
    - style_weights: list of weights to use for each layer in style_layers
    - tv_weight: weight of total variation regularization term
    - init_random: initialize the starting image to uniform random noise
    """
    # Extract features from the content image
    content_img = preprocess_image(load_image(content_image, size=image_size))
    feats = extract_features(content_img[None], model)
    content_target = feats[content_layer]
    
    # Extract features from the style image
    style_img = preprocess_image(load_image(style_image, size=style_size))
    s_feats = extract_features(style_img[None], model)
    style_targets = []
    # Compute list of TensorFlow Gram matrices
    for idx in style_layers:
        style_targets.append(gram_matrix(s_feats[idx]))
    
    # Set up optimization hyperparameters
    initial_lr = 3.0
    decayed_lr = 0.1
    decay_lr_at = 180
    max_iter = 200
    
    step = tf.Variable(0, trainable=False)
    boundaries = [decay_lr_at]
    values = [initial_lr, decayed_lr]
    learning_rate_fn = tf.keras.optimizers.schedules.PiecewiseConstantDecay(boundaries, values)

    # Later, whenever we perform an optimization step, we pass in the step.
    learning_rate = learning_rate_fn(step)

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        
    # Initialize the generated image and optimization variables
    
    f, axarr = plt.subplots(1,2)
    axarr[0].axis('off')
    axarr[1].axis('off')
    axarr[0].set_title('Content Source Img.')
    axarr[1].set_title('Style Source Img.')
    axarr[0].imshow(deprocess_image(content_img))
    axarr[1].imshow(deprocess_image(style_img))
    plt.show()
    plt.figure()
    
    # Initialize generated image to content image
    if init_random:
        initializer = tf.random_uniform_initializer(0, 1)
        img = initializer(shape=content_img[None].shape)
        img_var = tf.Variable(img)
        print("Intializing randomly.")
    else:
        img_var = tf.Variable(content_img[None])
#         print(tf.math.reduce_max(img_var))
        print("Initializing with content image.")
        
    for t in range(max_iter):
        with tf.GradientTape() as tape:
            tape.watch(img_var)
            feats = extract_features(img_var, model)
            # Compute loss
            c_loss = content_loss(content_weight, feats[content_layer], content_target)
            s_loss = style_loss(feats, style_layers, style_targets, style_weights)
            t_loss = tv_loss(img_var, tv_weight)
            loss = c_loss + s_loss + t_loss
            print("tot_loss:{}".format(loss))
#             print(tape.watched_variables()[-1])
#             print(tape.watched_variables()[-2])

            
        # Compute gradient
        grad = tape.gradient(loss, img_var)
        optimizer.apply_gradients([(grad, img_var)])
        
        img_var.assign(tf.clip_by_value(img_var, -1.5, 1.5))
            
        if t % 100 == 0:
            print('Iteration {}'.format(t))
            plt.imshow(deprocess_image(img_var[0].numpy(), rescale=True))
            plt.axis('off')
            plt.show()
    print('Iteration {}'.format(t))    
    plt.imshow(deprocess_image(img_var[0].numpy(), rescale=True))
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Generate some pretty pictures!
#
# Try out `style_transfer` on the three different parameter sets below. Make sure to run all three cells. Feel free to add your own, but make sure to include the results of style transfer on the third parameter set (starry night) in your submitted notebook.
#
# * The `content_image` is the filename of content image.
# * The `style_image` is the filename of style image.
# * The `image_size` is the size of smallest image dimension of the content image (used for content loss and generated image).
# * The `style_size` is the size of smallest style image dimension.
# * The `content_layer` specifies which layer to use for content loss.
# * The `content_weight` gives weighting on content loss in the overall loss function. Increasing the value of this parameter will make the final image look more realistic (closer to the original content).
# * `style_layers` specifies a list of which layers to use for style loss.
# * `style_weights` specifies a list of weights to use for each layer in style_layers (each of which will contribute a term to the overall style loss). We generally use higher weights for the earlier style layers because they describe more local/smaller scale features, which are more important to texture than features over larger receptive fields. In general, increasing these weights will make the resulting image look less like the original content and more distorted towards the appearance of the style image.
# * `tv_weight` specifies the weighting of total variation regularization in the overall loss function. Increasing this value makes the resulting image look smoother and less jagged, at the cost of lower fidelity to style and content.
#
# Below the next three cells of code (in which you shouldn't change the hyperparameters), feel free to copy and paste the parameters to play around them and see how the resulting image changes.

# %%
# Composition VII + Tubingen
params1 = {
    'content_image' : 'styles/tubingen.jpg',
    'style_image' : 'styles/composition_vii.jpg',
    'image_size' : 192,
    'style_size' : 512,
    'content_layer' : 2,
    'content_weight' : 5e-2, 
    'style_layers' : (0, 3, 5, 6),
    'style_weights' : (20000, 500, 12, 1),
    'tv_weight' : 5e-2
}

style_transfer(**params1)
# Out:
# Initializing with content image.
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28109.6640625
# Iteration 0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:4562435.5
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:1296414.0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:2967952.25
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:1361700.25
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:900163.0625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:733229.8125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:613878.6875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:512691.5625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:431573.375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:367612.03125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:316081.1875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:275976.65625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:245560.5
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:219958.1875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:197482.90625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:178099.21875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:161998.0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:148150.4375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:135970.78125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:125057.609375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:115538.3359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:107185.0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:99692.8046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:92890.0859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:86783.5625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:81340.6171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:76350.2734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:71742.2890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:67319.0859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:63262.3046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:59582.34375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:56155.84375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:53056.80078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:50139.609375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:47363.3046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:44708.578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:42296.32421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:40117.05859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:38043.3046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:36039.5390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:34196.12890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:32424.998046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:30803.046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29282.435546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27888.73828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26579.62890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25360.080078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24253.5703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23189.029296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22250.6484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21358.1171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20516.376953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19763.693359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19023.017578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18431.931640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17872.599609375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17488.712890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17142.01953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16889.634765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16610.341796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16197.7626953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15998.8134765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15601.5419921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15647.90234375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15412.2099609375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15807.8984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15599.8251953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15840.1796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15484.701171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15957.92578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15731.3447265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16023.388671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15697.1416015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16126.26953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:15849.7431640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16497.783203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16160.5380859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16942.625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16694.8203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17385.337890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16976.48046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17733.1484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17099.85546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17691.103515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17141.5703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17577.927734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17006.533203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17333.7265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16752.6171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17473.44140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:16779.66015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17604.2109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17173.4375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18063.5703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17630.201171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18663.921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17913.189453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18573.36328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17888.142578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18733.298828125
# Iteration 100
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17897.478515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18711.017578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17842.888671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18831.095703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:17925.90234375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19038.919921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18189.453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19498.708984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18853.634765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20209.10546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19263.087890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20439.537109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19247.58203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19911.576171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18854.255859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19778.056640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18718.62890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20326.212890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:18867.966796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20095.091796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19149.11328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20300.021484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19034.158203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20459.4296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19409.392578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21042.904296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19930.6015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21603.19140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20479.427734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21693.990234375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20369.00390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21257.55859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:19908.33984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21517.212890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20086.3203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21949.931640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20521.64453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22249.44921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20944.755859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22402.734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20880.828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22447.7265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20914.751953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21855.876953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20339.603515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21497.166015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20158.09765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21806.205078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:20463.28125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22409.775390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21037.814453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22554.068359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21304.71875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22484.869140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21038.6171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23007.80859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21150.734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23212.69140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21761.203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23683.501953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22156.947265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23487.34375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22220.7421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23361.419921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21872.236328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23552.873046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21919.791015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23707.625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22060.6328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23894.947265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22074.6953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24045.46484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22524.384765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24210.701171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22517.837890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24504.73828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22522.302734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24331.3046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22489.953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24375.794921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22926.166015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25181.162109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23485.345703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25742.58984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23737.08984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25531.798828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23592.6796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25010.806640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23317.056640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24869.865234375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22846.14453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24697.998046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22997.05078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25135.279296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23332.0546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25372.345703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23461.1875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24965.3125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23356.849609375
# Iteration 199

# %%
# Scream + Tubingen
params2 = {
    'content_image':'styles/tubingen.jpg',
    'style_image':'styles/the_scream.jpg',
    'image_size':192,
    'style_size':224,
    'content_layer':2,
    'content_weight':3e-2,
    'style_layers':[0, 3, 5, 6],
    'style_weights':[200000, 800, 12, 1],
    'tv_weight':2e-2
}

style_transfer(**params2)
# Out:
# Initializing with content image.
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:63302.4609375
# Iteration 0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:5869430.5
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:1498228.5
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:3992875.0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:1756031.25
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:1153934.0
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:972183.4375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:819573.25
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:672264.875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:555615.3125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:459490.03125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:383520.0625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:326037.0625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:282261.84375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:247233.578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:219249.46875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:196357.484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:176453.609375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:158904.03125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:144250.515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:131637.4375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:120819.75
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:111595.4765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:103145.734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:95777.109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:88843.3046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:82481.734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:77224.5234375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:72342.7734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:67775.8359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:63513.01953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:59739.3125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:56361.5703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:53334.140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:50398.2421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:47855.625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:45355.2265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:43120.3359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:41169.2421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:39301.578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:37529.6640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:36058.515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:34517.04296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:33265.04296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:31882.455078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:30733.69921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29668.328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28639.4375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27626.27734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26722.69140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25825.810546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25040.189453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24217.443359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23576.837890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22812.48828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22412.8984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21836.80078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22873.1015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22149.224609375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27100.587890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23947.931640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27745.912109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25176.859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26505.6796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24914.373046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25029.638671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23595.984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23921.443359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22484.87890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23843.908203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22268.330078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25044.484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22428.75390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24932.767578125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22961.845703125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25382.38671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23117.935546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25390.318359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22911.8125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24875.1875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22610.80859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24973.853515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22712.841796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25506.091796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22751.375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25331.138671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22863.72265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24687.3125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22568.16796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24643.623046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22372.798828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24766.5
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22322.744140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25049.482421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22533.21875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25705.28515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22725.529296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25421.958984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22821.537109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25288.833984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22674.1328125
# Iteration 100
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25034.552734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22533.326171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25645.810546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22584.919921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25901.65234375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23167.828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25881.029296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22846.1171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25131.89453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22618.3125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24668.318359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22093.837890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24877.4375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:21984.1796875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26005.79296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23045.271484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26238.94140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23309.33984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25949.326171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23000.943359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25367.6328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22857.111328125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25374.654296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22661.955078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25660.123046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22401.958984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25854.28125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22744.625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25896.533203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23230.28515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26191.296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23190.478515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26627.44140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23277.0078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25951.509765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:22983.900390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26424.333984375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23117.85546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26888.025390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23511.572265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26521.326171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23589.84765625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26591.287109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23179.68359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26906.548828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23299.814453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26857.34375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23572.25390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27345.0546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23819.818359375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26720.306640625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23710.8515625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26701.173828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23456.046875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26788.048828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23384.205078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26932.548828125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23497.310546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27360.58203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23966.630859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26924.076171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23765.51953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27482.263671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23772.013671875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27455.734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24041.416015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26925.001953125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23523.783203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26754.587890625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23240.58203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27907.30859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24010.30859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28965.62109375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25158.669921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28775.919921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25115.46875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28342.2421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24629.0546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26868.369140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23851.439453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:26894.54296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:23292.4296875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:27919.7734375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24183.408203125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29719.46875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25166.791015625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29898.51171875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25990.564453125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28657.96484375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25276.07421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29465.607421875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25116.322265625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29898.80078125
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25440.0390625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28575.5859375
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:25050.85546875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:28279.69140625
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:24510.669921875
# tf.Tensor(0.0, shape=(), dtype=float32)
# tot_loss:29040.833984375
# Iteration 199

# %%
# Starry Night + Tubingen
params3 = {
    'content_image' : 'styles/tubingen.jpg',
    'style_image' : 'styles/starry_night.jpg',
    'image_size' : 192,
    'style_size' : 192,
    'content_layer' : 2,
    'content_weight' : 6e-2,
    'style_layers' : [0, 3, 5, 6],
    'style_weights' : [300000, 1000, 15, 3],
    'tv_weight' : 2e-2
}

style_transfer(**params3)
# Out:
# Initializing with content image.
# Iteration 0
# Iteration 100
# Iteration 199

# %%
# Starry Night + Tubingen
params4 = {
    'content_image' : 'styles/tubingen.jpg',
    'style_image' : 'styles/starry_night.jpg',
    'image_size' : 192,
    'style_size' : 192,
    'content_layer' : 3,
    'content_weight' : 6e-2,
    'style_layers' : [1, 4, 6, 7],
    'style_weights' : [300000, 1000, 15, 3],
    'tv_weight' : 2e-2
}

style_transfer(**params4)
# Out:
# Initializing with content image.
# Iteration 0
# Iteration 100
# Iteration 199

# %% [markdown]
# ## Feature Inversion
#
# The code you've written can do another cool thing. In an attempt to understand the types of features that convolutional networks learn to recognize, a recent paper [1] attempts to reconstruct an image from its feature representation. We can easily implement this idea using image gradients from the pretrained network, which is exactly what we did above (but with two different feature representations).
#
# Now, if you set the style weights to all be 0 and initialize the starting image to random noise instead of the content source image, you'll reconstruct an image from the feature representation of the content source image. You're starting with total noise, but you should end up with something that looks quite a bit like your original image.
#
# (Similarly, you could do "texture synthesis" from scratch if you set the content weight to 0 and initialize the starting image to random noise, but we won't ask you to do that here.)
#
# Run the following cell to try out feature inversion.
#
# [1] Aravindh Mahendran, Andrea Vedaldi, "Understanding Deep Image Representations by Inverting them", CVPR 2015

# %%
# Feature Inversion -- Starry Night + Tubingen
params_inv = {
    'content_image' : 'styles/tubingen.jpg',
    'style_image' : 'styles/starry_night.jpg',
    'image_size' : 192,
    'style_size' : 192,
    'content_layer' : 2,
    'content_weight' : 6e-2,
    'style_layers' : [0, 3, 5, 6],
    'style_weights' : [0, 0, 0, 0], # we discard any contributions from style to the loss
    'tv_weight' : 2e-2,
    'init_random': True # we want to initialize our image to be random
}

style_transfer(**params_inv)
# Out:
# Intializing randomly.
# Iteration 0
# Iteration 100
# Iteration 199

# %%
x = tf.constant(3.0)
with tf.GradientTape() as g:
  g.watch(x)
  y = x * x
dy_dx = g.gradient(y, x) # Will compute to 6.0
print(dy_dx)
# Out:
# tf.Tensor(6.0, shape=(), dtype=float32)

# %%
x = tf.Variable(3.0)
x=x-1
print("x={}, type = {}".format(x, type(x)))

z = tf.Variable(3.0)
z.assign_sub(1)
print("z={}".format(z))
with tf.GradientTape() as g:
  w = z * z  
  y = x * x
dy_dx, dw_dz = g.gradient([y,w], [x,z]) # Will compute to 6.0

print("dy_dx={}".format(dy_dx))
print("dw_dz={}".format(dw_dz))
# Out:
# x=2.0, type = <class 'tensorflow.python.framework.ops.EagerTensor'>
# z=<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=2.0>
# dy_dx=None
# dw_dz=4.0

# %%
x = tf.Variable(3.0)
x=x-1
print("x={}, type = {}".format(x, type(x)))

z = tf.Variable(3.0)
z.assign_sub(1)
print("z={}".format(z))
with tf.GradientTape() as g:
  g.watch(x)
  w = z * z  
  y = x * x
dy_dx, dw_dz = g.gradient([y,w], [x,z]) # Will compute to 6.0

print("dy_dx={}".format(dy_dx))
print("dw_dz={}".format(dw_dz))
# Out:
# x=2.0, type = <class 'tensorflow.python.framework.ops.EagerTensor'>
# z=<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=2.0>
# dy_dx=4.0
# dw_dz=4.0

# %%
x = tf.Variable(3.0)
x=x-1
print("x={}, type = {}".format(x, type(x)))


with tf.GradientTape() as g:
  z = tf.Variable(3.0)
  z.assign_sub(1)
  print("z={}".format(z))
  w = z * z  
  y = x * x
dy_dx, dw_dz = g.gradient([y,w], [x,z]) # Will compute to 6.0

print("dy_dx={}".format(dy_dx))
print("dw_dz={}".format(dw_dz))
# Out:
# x=2.0, type = <class 'tensorflow.python.framework.ops.EagerTensor'>
# z=<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=2.0>
# dy_dx=None
# dw_dz=4.0

# %%
a = tf.Variable(2.0)
# Out:
# <tf.Tensor: id=1274335, shape=(), dtype=float32, numpy=4.0>

# %%
def test_fun(x):
    t = tf.Variable(0.0, name="t")
    t.assign_add(x**2)
    
    t.assign_add(x+1)
    
    return t


x = tf.Variable(2.0)

for i in range(2):

    with tf.GradientTape() as tape:
        tape.watch(x)
        t1 = test_fun(x)
        loss = x + t1
        print(loss)
    
    dt,dx = tape.gradient(loss, [t1, x])
    print("dt:{}".format(dt))
    print("dx:{}".format(dt))
# Out:
# dt:1.0
# dx:1.0
# dt:1.0
# dx:1.0
